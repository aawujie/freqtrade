# %% [markdown]
# ## 环境变量设置

# %% [markdown]
# ## 1. 下载数据
#
# - --erase：重下，覆盖式（先删再下）。
# - --prepend：在已有数据前面补更早历史，保留现有数据。

# %%
# !docker compose run --rm freqtrade download-data \
  --config /freqtrade/user_data/config_backtest.json \
  --trading-mode futures \
  --timeframe 5m \
  --data-format-ohlcv feather \
  --pairs ASTER/USDT:USDT \
  --timerange 20250901-20250923 \
  --erase
# Out:
# 2025-09-24 07:04:05,812 - freqtrade - INFO - freqtrade
# docker-2025.9-dev-f6e1442f
# 2025-09-24 07:04:06,557 - numexpr.utils - INFO - NumExpr defaulting to 10
# threads.
# 2025-09-24 07:04:07,869 - freqtrade.configuration.load_config - INFO - Using
# config: /freqtrade/user_data/config_backtest.json ...
# 2025-09-24 07:04:07,872 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__JWT_SECRET_KEY'
# 2025-09-24 07:04:07,872 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'JWT_SECRET_KEY']
# 2025-09-24 07:04:07,872 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__LISTEN_IP_ADDRESS'
# 2025-09-24 07:04:07,873 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'LISTEN_IP_ADDRESS']
# 2025-09-24 07:04:07,873 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__LISTEN_PORT'
# 2025-09-24 07:04:07,873 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'LISTEN_PORT']
# 2025-09-24 07:04:07,874 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__WS_TOKEN'
# 2025-09-24 07:04:07,874 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'WS_TOKEN']
# 2025-09-24 07:04:07,874 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__EXCHANGE__KEY'
# 2025-09-24 07:04:07,874 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['EXCHANGE', 'KEY']
# 2025-09-24 07:04:07,875 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__EXCHANGE__SECRET'
# 2025-09-24 07:04:07,875 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['EXCHANGE', 'SECRET']
# 2025-09-24 07:04:07,875 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__TELEGRAM__CHAT_ID'
# 2025-09-24 07:04:07,876 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['TELEGRAM', 'CHAT_ID']
# 2025-09-24 07:04:07,876 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__TELEGRAM__TOKEN'
# 2025-09-24 07:04:07,876 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['TELEGRAM', 'TOKEN']
# 2025-09-24 07:04:07,877 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__WEBHOOK__URL'
# 2025-09-24 07:04:07,877 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['WEBHOOK', 'URL']
# 2025-09-24 07:04:07,878 - freqtrade.loggers - INFO - Enabling colorized output.
# 2025-09-24 07:04:07,878 - freqtrade.loggers - INFO - Logfile configured
# 2025-09-24 07:04:07,878 - freqtrade.loggers - INFO - Verbosity set to 0
# 2025-09-24 07:04:07,879 - freqtrade.configuration.configuration - INFO -
# Parameter --timerange detected: 20250901-20250923 ...
# 2025-09-24 07:04:08,045 - freqtrade.configuration.configuration - INFO - Using
# user-data directory: /freqtrade/user_data ...
# 2025-09-24 07:04:08,046 - freqtrade.configuration.configuration - INFO - Using
# data directory: /freqtrade/user_data/data/binance ...
# 2025-09-24 07:04:08,046 - freqtrade.configuration.configuration - INFO - Using
# pairs ['ASTER/USDT:USDT']
# 2025-09-24 07:04:08,046 - freqtrade.configuration.configuration - INFO - Erase
# detected. Deleting existing data.
# 2025-09-24 07:04:08,047 - freqtrade.configuration.configuration - INFO -
# timeframes --timeframes: ['5m']
# 2025-09-24 07:04:08,047 - freqtrade.configuration.configuration - INFO - Using
# "feather" to store OHLCV data.
# 2025-09-24 07:04:08,047 - freqtrade.configuration.configuration - INFO -
# Detected --trading-mode: futures
# 2025-09-24 07:04:08,048 - freqtrade.configuration.configuration - INFO - Filter
# trades by timerange: 20250901-20250923
# 2025-09-24 07:04:08,049 - freqtrade.exchange.check_exchange - INFO - Checking
# exchange...
# 2025-09-24 07:04:08,058 - freqtrade.exchange.check_exchange - INFO - Exchange
# "binance" is officially supported by the Freqtrade development team.
# 2025-09-24 07:04:08,059 - freqtrade.configuration.config_validation - INFO -
# Validating configuration ...
# 2025-09-24 07:04:08,189 - freqtrade.exchange.exchange - INFO - Instance is
# running with dry_run enabled
# 2025-09-24 07:04:08,190 - freqtrade.exchange.exchange - INFO - Using CCXT 4.5.4
# 2025-09-24 07:04:08,190 - freqtrade.exchange.exchange - INFO - Applying
# additional ccxt config: {'options': {'defaultType': 'swap'}}
# 2025-09-24 07:04:08,198 - freqtrade.exchange.exchange - INFO - Applying
# additional ccxt config: {'options': {'defaultType': 'swap'}}
# 2025-09-24 07:04:08,209 - freqtrade.exchange.exchange - INFO - Using Exchange
# "Binance"
# 2025-09-24 07:04:08,209 - freqtrade.resolvers.exchange_resolver - INFO - Using
# resolved exchange 'Binance'...
# 2025-09-24 07:04:08,210 - freqtrade.exchange.exchange - INFO - Markets were not
# loaded. Loading them now..
# 2025-09-24 07:04:10,450 - freqtrade.data.history.history_utils - INFO - About to
# download pairs: ['ASTER/USDT:USDT'], intervals: ['5m'] to
# /freqtrade/user_data/data/binance
# Timeframe           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:00 • -:--:--
# 2025-09-24 07:04:10,523 - freqtrade.data.history.history_utils - INFO - Download
# history data for "ASTER/USDT:USDT", 5m, futures and store in
# /freqtrade/user_data/data/binance. From 2025-09-01T00:00:00 to
# 2025-09-23T00:00:00
# Timeframe           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:00 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:00 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:00 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:00 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:00 • -:--:--
# 2025-09-24 07:04:10,972 - freqtrade.exchange.binance - INFO - Candle-data for
# ASTER/USDT:USDT available starting with 2025-09-19T12:00:00+00:00.
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:00 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:00 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:00 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:00 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:00 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:00 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:01 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:01 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:01 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:01 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:01 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:01 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:01 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:01 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:01 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:02 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:02 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:02 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:02 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:02 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:02 • -:--:--
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:02 • -:--:--
# 2025-09-24 07:04:13,220 - freqtrade.data.history.history_utils - INFO -
# Downloaded data for ASTER/USDT:USDT with length 1380.
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:02 • -:--:--
# 2025-09-24 07:04:13,246 - freqtrade.data.history.history_utils - INFO - Download
# history data for "ASTER/USDT:USDT", 8h, funding_rate and store in
# /freqtrade/user_data/data/binance. From 2025-09-01T00:00:00 to
# 2025-09-23T00:00:00
# Timeframe 5m                ━━━━━━━━━━━━━━━━━━━━━━━ 0/3   0% • 0:00:02 • -:--:--
# Timeframe 5m                ━━━━━━━╸━━━━━━━━━━━━━━━ 1/3  33% • 0:00:02 • -:--:--
# Timeframe 5m                ━━━━━━━╸━━━━━━━━━━━━━━━ 1/3  33% • 0:00:02 • -:--:--
# Timeframe 5m                ━━━━━━━╸━━━━━━━━━━━━━━━ 1/3  33% • 0:00:03 • -:--:--
# Timeframe 5m                ━━━━━━━╸━━━━━━━━━━━━━━━ 1/3  33% • 0:00:03 • -:--:--
# Timeframe 5m                ━━━━━━━╸━━━━━━━━━━━━━━━ 1/3  33% • 0:00:03 • -:--:--
# Timeframe 5m                ━━━━━━━╸━━━━━━━━━━━━━━━ 1/3  33% • 0:00:03 • -:--:--
# Timeframe 5m                ━━━━━━━╸━━━━━━━━━━━━━━━ 1/3  33% • 0:00:03 • -:--:--
# 2025-09-24 07:04:14,027 - freqtrade.data.history.history_utils - INFO -
# Downloaded data for ASTER/USDT:USDT with length 28.
# Timeframe 5m                ━━━━━━━╸━━━━━━━━━━━━━━━ 1/3  33% • 0:00:03 • -:--:--
# 2025-09-24 07:04:14,035 - freqtrade.data.history.history_utils - INFO - Download
# history data for "ASTER/USDT:USDT", 8h, mark and store in
# /freqtrade/user_data/data/binance. From 2025-09-01T00:00:00 to
# 2025-09-23T00:00:00
# Timeframe 5m                ━━━━━━━╸━━━━━━━━━━━━━━━ 1/3  33% • 0:00:03 • -:--:--
# Timeframe funding_rate, 8h  ━━━━━━━━━━━━━━━╺━━━━━━━ 2/3  67% • 0:00:03 • 0:00:01
# Timeframe funding_rate, 8h  ━━━━━━━━━━━━━━━╺━━━━━━━ 2/3  67% • 0:00:03 • 0:00:01
# Timeframe funding_rate, 8h  ━━━━━━━━━━━━━━━╺━━━━━━━ 2/3  67% • 0:00:03 • 0:00:01
# Timeframe funding_rate, 8h  ━━━━━━━━━━━━━━━╺━━━━━━━ 2/3  67% • 0:00:03 • 0:00:01
# 2025-09-24 07:04:14,385 - freqtrade.exchange.binance - INFO - Candle-data for
# ASTER/USDT:USDT available starting with 2025-09-19T08:00:00+00:00.
# Timeframe funding_rate, 8h  ━━━━━━━━━━━━━━━╺━━━━━━━ 2/3  67% • 0:00:03 • 0:00:01
# Timeframe funding_rate, 8h  ━━━━━━━━━━━━━━━╺━━━━━━━ 2/3  67% • 0:00:03 • 0:00:01
# Timeframe funding_rate, 8h  ━━━━━━━━━━━━━━━╺━━━━━━━ 2/3  67% • 0:00:04 • 0:00:01
# Timeframe funding_rate, 8h  ━━━━━━━━━━━━━━━╺━━━━━━━ 2/3  67% • 0:00:04 • 0:00:01
# Timeframe funding_rate, 8h  ━━━━━━━━━━━━━━━╺━━━━━━━ 2/3  67% • 0:00:04 • 0:00:01
# Timeframe funding_rate, 8h  ━━━━━━━━━━━━━━━╺━━━━━━━ 2/3  67% • 0:00:04 • 0:00:01
# Timeframe funding_rate, 8h  ━━━━━━━━━━━━━━━╺━━━━━━━ 2/3  67% • 0:00:04 • 0:00:01
# 2025-09-24 07:04:15,146 - freqtrade.data.history.history_utils - INFO -
# Downloaded data for ASTER/USDT:USDT with length 14.
# Timeframe funding_rate, 8h  ━━━━━━━━━━━━━━━╺━━━━━━━ 2/3  67% • 0:00:04 • 0:00:01
# Timeframe funding_rate, 8h  ━━━━━━━━━━━━━━━╺━━━━━━━ 2/3  67% • 0:00:04 • 0:00:01
# Timeframe                   ━━━━━━━━━━━━━━━━━━━━━━━ 3/3 100% • 0:00:04 • 0:00:00
# Downloading ASTER/USDT:USDT ━━━━━━━━━━━━━━━━━━━━━━━ 1/1 100% • 0:00:04 • 0:00:00

# %%
# !docker compose run --rm freqtrade download-data \
  --config /freqtrade/user_data/config_backtest.json \
  --trading-mode spot \
  --timeframe 5m \
  --data-format-ohlcv feather \
  --pairs ETH/USDT BTC/USDT \
  --prepend \
  --timerange 20240101-20241231
# Out:
# 2025-09-21 15:11:28,075 - freqtrade - INFO - freqtrade
# docker-2025.9-dev-f6e1442f
# 2025-09-21 15:11:28,399 - numexpr.utils - INFO - NumExpr defaulting to 10
# threads.
# 2025-09-21 15:11:29,221 - freqtrade.configuration.load_config - INFO - Using
# config: /freqtrade/user_data/config_backtest.json ...
# 2025-09-21 15:11:29,222 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__JWT_SECRET_KEY'
# 2025-09-21 15:11:29,222 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'JWT_SECRET_KEY']
# 2025-09-21 15:11:29,223 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__LISTEN_IP_ADDRESS'
# 2025-09-21 15:11:29,223 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'LISTEN_IP_ADDRESS']
# 2025-09-21 15:11:29,223 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__LISTEN_PORT'
# 2025-09-21 15:11:29,224 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'LISTEN_PORT']
# 2025-09-21 15:11:29,224 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__WS_TOKEN'
# 2025-09-21 15:11:29,224 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'WS_TOKEN']
# 2025-09-21 15:11:29,224 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__EXCHANGE__KEY'
# 2025-09-21 15:11:29,225 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['EXCHANGE', 'KEY']
# 2025-09-21 15:11:29,225 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__EXCHANGE__SECRET'
# 2025-09-21 15:11:29,225 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['EXCHANGE', 'SECRET']
# 2025-09-21 15:11:29,225 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__TELEGRAM__CHAT_ID'
# 2025-09-21 15:11:29,226 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['TELEGRAM', 'CHAT_ID']
# 2025-09-21 15:11:29,226 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__TELEGRAM__TOKEN'
# 2025-09-21 15:11:29,226 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['TELEGRAM', 'TOKEN']
# 2025-09-21 15:11:29,227 - freqtrade.loggers - INFO - Enabling colorized output.
# 2025-09-21 15:11:29,228 - freqtrade.loggers - INFO - Logfile configured
# 2025-09-21 15:11:29,228 - freqtrade.loggers - INFO - Verbosity set to 0
# 2025-09-21 15:11:29,228 - freqtrade.configuration.configuration - INFO -
# Parameter --timerange detected: 20240101-20241231 ...
# 2025-09-21 15:11:29,275 - freqtrade.configuration.configuration - INFO - Using
# user-data directory: /freqtrade/user_data ...
# 2025-09-21 15:11:29,276 - freqtrade.configuration.configuration - INFO - Using
# data directory: /freqtrade/user_data/data/binance ...
# 2025-09-21 15:11:29,277 - freqtrade.configuration.configuration - INFO - Using
# pairs ['ETH/USDT', 'BTC/USDT']
# 2025-09-21 15:11:29,277 - freqtrade.configuration.configuration - INFO - Prepend
# detected. Allowing data prepending.
# 2025-09-21 15:11:29,277 - freqtrade.configuration.configuration - INFO -
# timeframes --timeframes: ['5m']
# 2025-09-21 15:11:29,277 - freqtrade.configuration.configuration - INFO - Using
# "feather" to store OHLCV data.
# 2025-09-21 15:11:29,278 - freqtrade.configuration.configuration - INFO -
# Detected --trading-mode: spot
# 2025-09-21 15:11:29,278 - freqtrade.configuration.configuration - INFO - Filter
# trades by timerange: 20240101-20241231
# 2025-09-21 15:11:29,279 - freqtrade.exchange.check_exchange - INFO - Checking
# exchange...
# 2025-09-21 15:11:29,289 - freqtrade.exchange.check_exchange - INFO - Exchange
# "binance" is officially supported by the Freqtrade development team.
# 2025-09-21 15:11:29,289 - freqtrade.configuration.config_validation - INFO -
# Validating configuration ...
# 2025-09-21 15:11:29,372 - freqtrade.exchange.exchange - INFO - Instance is
# running with dry_run enabled
# 2025-09-21 15:11:29,373 - freqtrade.exchange.exchange - INFO - Using CCXT 4.5.4
# 2025-09-21 15:11:29,389 - freqtrade.exchange.exchange - INFO - Using Exchange
# "Binance"
# 2025-09-21 15:11:29,390 - freqtrade.resolvers.exchange_resolver - INFO - Using
# resolved exchange 'Binance'...
# 2025-09-21 15:11:29,390 - freqtrade.exchange.exchange - INFO - Markets were not
# loaded. Loading them now..
# 2025-09-21 15:11:36,868 - freqtrade.data.history.history_utils - INFO - About to
# download pairs: ['ETH/USDT', 'BTC/USDT'], intervals: ['5m'] to
# /freqtrade/user_data/data/binance
# Timeframe           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:00 • -:--:--
# 2025-09-21 15:11:36,914 - freqtrade.data.history.history_utils - INFO - Download
# history data for "ETH/USDT", 5m, spot and store in
# /freqtrade/user_data/data/binance. From 2024-01-01T00:00:00 to
# 2025-08-22T00:00:00
# Timeframe           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:00 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:00 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:00 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:00 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:00 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:00 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:00 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:00 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:00 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:00 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:01 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:01 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:01 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:01 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:01 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:01 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:01 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:01 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:01 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:02 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:02 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:02 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:02 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:02 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:02 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:02 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:02 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:02 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:02 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:03 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:03 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:03 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:03 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:03 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:03 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:03 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:03 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:03 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:04 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:04 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:04 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:04 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:04 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:04 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:04 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:04 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:04 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:05 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:05 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:05 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:05 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:05 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:05 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:05 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:05 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:05 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:06 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:06 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:06 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:06 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:06 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:06 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:06 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:06 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:06 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:06 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:07 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:07 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:07 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:07 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:07 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:07 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:07 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:07 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:07 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:08 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:08 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:08 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:08 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:08 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:08 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:08 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:08 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:08 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:09 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:09 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:09 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:09 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:09 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:09 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:09 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:09 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:09 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:09 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:10 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:10 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:10 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:10 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:10 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:10 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:10 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:10 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:10 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:11 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:11 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:11 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:11 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:11 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:11 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:11 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:11 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:11 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:11 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:12 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:12 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:12 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:12 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:12 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:12 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:12 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:12 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:12 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:13 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:13 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:13 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:13 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:13 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:13 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:13 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:13 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:13 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:13 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:14 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:14 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:14 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:14 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:14 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:14 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:14 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:14 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:14 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:15 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:15 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:15 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:15 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:15 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:15 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:15 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:15 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:15 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:16 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:16 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:16 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:16 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:16 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:16 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:16 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:16 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:16 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:16 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:17 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:17 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:17 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:17 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:17 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:17 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:17 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:17 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:17 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:18 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:18 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:18 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:18 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:18 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:18 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:18 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:18 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:18 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:19 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:19 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:19 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:19 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:19 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:19 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:19 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:19 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:19 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:19 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • -:--:--
# 2025-09-21 15:11:57,002 - freqtrade.data.history.history_utils - INFO -
# Downloaded data for ETH/USDT with length 172512.
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • -:--:--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00
# 2025-09-21 15:11:57,195 - freqtrade.data.history.history_utils - INFO - Download--
# history data for "BTC/USDT", 5m, spot and store in
# /freqtrade/user_data/data/binance. From 2024-01-01T00:00:00 to
# 2025-08-22T05:05:00
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# 2025-09-21 15:12:07,679 - freqtrade.data.history.history_utils - INFO - 36m-:--:--
# Downloaded data for BTC/USDT with length 172573.
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe 5m         ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/1   0% • 0:00:20 • 0:00:00--
# Timeframe            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/1 100% • 0:00:20 • 0:00:00--
# Downloading BTC/USDT ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 100% • 0:00:30 • 0:00:00

# %% [markdown]
# ## 2. BackTest

# %%
# !docker compose run --rm freqtrade backtesting \
  --config /freqtrade/user_data/config_backtest.json \
  --strategy DoubleMAStrategy \
  --timeframe 5m \
  --timerange 20240901-20241231
# Out:
# [+] Creating 1/1
#  ✔ Network freqtrade-ws_default  Created                                   0.0s
# 2025-09-23 02:58:49,874 - freqtrade - INFO - freqtrade
# docker-2025.9-dev-f6e1442f
# 2025-09-23 02:58:50,281 - numexpr.utils - INFO - NumExpr defaulting to 10
# threads.
# 2025-09-23 02:58:51,369 - freqtrade.configuration.load_config - INFO - Using
# config: /freqtrade/user_data/config_backtest.json ...
# 2025-09-23 02:58:51,371 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__JWT_SECRET_KEY'
# 2025-09-23 02:58:51,371 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'JWT_SECRET_KEY']
# 2025-09-23 02:58:51,371 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__LISTEN_IP_ADDRESS'
# 2025-09-23 02:58:51,371 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'LISTEN_IP_ADDRESS']
# 2025-09-23 02:58:51,371 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__LISTEN_PORT'
# 2025-09-23 02:58:51,372 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'LISTEN_PORT']
# 2025-09-23 02:58:51,372 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__WS_TOKEN'
# 2025-09-23 02:58:51,372 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'WS_TOKEN']
# 2025-09-23 02:58:51,372 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__EXCHANGE__KEY'
# 2025-09-23 02:58:51,373 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['EXCHANGE', 'KEY']
# 2025-09-23 02:58:51,373 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__EXCHANGE__SECRET'
# 2025-09-23 02:58:51,373 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['EXCHANGE', 'SECRET']
# 2025-09-23 02:58:51,373 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__TELEGRAM__CHAT_ID'
# 2025-09-23 02:58:51,373 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['TELEGRAM', 'CHAT_ID']
# 2025-09-23 02:58:51,373 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__TELEGRAM__TOKEN'
# 2025-09-23 02:58:51,374 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['TELEGRAM', 'TOKEN']
# 2025-09-23 02:58:51,374 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__WEBHOOK__URL'
# 2025-09-23 02:58:51,374 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['WEBHOOK', 'URL']
# 2025-09-23 02:58:51,375 - freqtrade.loggers - INFO - Enabling colorized output.
# 2025-09-23 02:58:51,375 - freqtrade.loggers - INFO - Logfile configured
# 2025-09-23 02:58:51,376 - freqtrade.loggers - INFO - Verbosity set to 0
# 2025-09-23 02:58:51,376 - freqtrade.configuration.configuration - INFO -
# Parameter -i/--timeframe detected ... Using timeframe: 5m ...
# 2025-09-23 02:58:51,376 - freqtrade.configuration.configuration - INFO - Using
# max_open_trades: 3 ...
# 2025-09-23 02:58:51,376 - freqtrade.configuration.configuration - INFO -
# Parameter --timerange detected: 20240901-20241231 ...
# 2025-09-23 02:58:51,434 - freqtrade.configuration.configuration - INFO - Using
# user-data directory: /freqtrade/user_data ...
# 2025-09-23 02:58:51,435 - freqtrade.configuration.configuration - INFO - Using
# data directory: /freqtrade/user_data/data/binance ...
# 2025-09-23 02:58:51,435 - freqtrade.configuration.configuration - INFO -
# Parameter --cache=day detected ...
# 2025-09-23 02:58:51,436 - freqtrade.configuration.configuration - INFO - Filter
# trades by timerange: 20240901-20241231
# 2025-09-23 02:58:51,436 - freqtrade.exchange.check_exchange - INFO - Checking
# exchange...
# 2025-09-23 02:58:51,444 - freqtrade.exchange.check_exchange - INFO - Exchange
# "binance" is officially supported by the Freqtrade development team.
# 2025-09-23 02:58:51,444 - freqtrade.configuration.configuration - INFO - Using
# pairlist from configuration.
# 2025-09-23 02:58:51,445 - freqtrade.configuration.config_validation - INFO -
# Validating configuration ...
# 2025-09-23 02:58:51,446 - freqtrade.commands.optimize_commands - INFO - Starting
# freqtrade in Backtesting mode
# 2025-09-23 02:58:51,446 - freqtrade.exchange.exchange - INFO - Instance is
# running with dry_run enabled
# 2025-09-23 02:58:51,446 - freqtrade.exchange.exchange - INFO - Using CCXT 4.5.4
# 2025-09-23 02:58:51,447 - freqtrade.exchange.exchange - INFO - Applying
# additional ccxt config: {'options': {'defaultType': 'swap'}}
# 2025-09-23 02:58:51,452 - freqtrade.exchange.exchange - INFO - Applying
# additional ccxt config: {'options': {'defaultType': 'swap'}}
# 2025-09-23 02:58:51,458 - freqtrade.exchange.exchange - INFO - Using Exchange
# "Binance"
# 2025-09-23 02:58:53,283 - freqtrade.resolvers.exchange_resolver - INFO - Using
# resolved exchange 'Binance'...
# 2025-09-23 02:58:53,298 - freqtrade.resolvers.iresolver - INFO - Using resolved
# strategy DoubleMAStrategy from
# '/freqtrade/user_data/strategies/DoubleMAStrategy.py'...
# 2025-09-23 02:58:53,299 - freqtrade.strategy.hyper - INFO - Loading parameters
# from file /freqtrade/user_data/strategies/DoubleMAStrategy.json
# 2025-09-23 02:58:53,299 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'timeframe' with value from the configuration: 5m.
# 2025-09-23 02:58:53,300 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'stake_currency' with value from the configuration: USDT.
# 2025-09-23 02:58:53,300 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'stake_amount' with value from the configuration: 100.
# 2025-09-23 02:58:53,300 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'unfilledtimeout' with value from the configuration: {'entry':
# 10, 'exit': 10, 'exit_timeout_count': 0, 'unit': 'minutes'}.
# 2025-09-23 02:58:53,300 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'max_open_trades' with value from the configuration: 3.
# 2025-09-23 02:58:53,300 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using minimal_roi: {'0': 0.537, '435': 0.154, '766': 0.028, '1692': 0}
# 2025-09-23 02:58:53,301 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using timeframe: 5m
# 2025-09-23 02:58:53,301 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stoploss: -0.204
# 2025-09-23 02:58:53,301 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_stop: True
# 2025-09-23 02:58:53,301 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_stop_positive: 0.033
# 2025-09-23 02:58:53,301 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_stop_positive_offset: 0.034
# 2025-09-23 02:58:53,301 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_only_offset_is_reached: False
# 2025-09-23 02:58:53,302 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using use_custom_stoploss: False
# 2025-09-23 02:58:53,302 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using process_only_new_candles: True
# 2025-09-23 02:58:53,302 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using order_types: {'entry': 'limit', 'exit': 'limit', 'stoploss':
# 'limit', 'stoploss_on_exchange': False, 'stoploss_on_exchange_interval': 60}
# 2025-09-23 02:58:53,302 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using order_time_in_force: {'entry': 'GTC', 'exit': 'GTC'}
# 2025-09-23 02:58:53,303 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stake_currency: USDT
# 2025-09-23 02:58:53,303 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stake_amount: 100
# 2025-09-23 02:58:53,303 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using startup_candle_count: 50
# 2025-09-23 02:58:53,303 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using unfilledtimeout: {'entry': 10, 'exit': 10, 'exit_timeout_count':
# 0, 'unit': 'minutes'}
# 2025-09-23 02:58:53,303 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using use_exit_signal: True
# 2025-09-23 02:58:53,303 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using exit_profit_only: False
# 2025-09-23 02:58:53,304 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using ignore_roi_if_entry_signal: False
# 2025-09-23 02:58:53,304 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using exit_profit_offset: 0.0
# 2025-09-23 02:58:53,304 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using disable_dataframe_checks: False
# 2025-09-23 02:58:53,304 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using ignore_buying_expired_candle_after: 0
# 2025-09-23 02:58:53,304 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using position_adjustment_enable: False
# 2025-09-23 02:58:53,304 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using max_entry_position_adjustment: -1
# 2025-09-23 02:58:53,304 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using max_open_trades: 3
# 2025-09-23 02:58:53,304 - freqtrade.configuration.config_validation - INFO -
# Validating configuration ...
# 2025-09-23 02:58:53,317 - freqtrade.resolvers.iresolver - INFO - Using resolved
# pairlist StaticPairList from
# '/freqtrade/freqtrade/plugins/pairlist/StaticPairList.py'...
# 2025-09-23 02:58:53,322 - freqtrade.optimize.backtesting - INFO - Using fee
# 0.0500% - worst case fee from exchange (lowest tier).
# 2025-09-23 02:58:53,368 - freqtrade.data.history.datahandlers.idatahandler -
# WARNING - BTC/USDT:USDT, futures, 5m, data starts at 2024-09-01 00:00:00
# 2025-09-23 02:58:53,368 - freqtrade.data.history.datahandlers.idatahandler -
# WARNING - BTC/USDT:USDT, futures, 5m, data ends at 2024-12-30 23:55:00
# 2025-09-23 02:58:53,395 - freqtrade.data.history.datahandlers.idatahandler -
# WARNING - ETH/USDT:USDT, futures, 5m, data starts at 2024-09-01 00:00:00
# 2025-09-23 02:58:53,395 - freqtrade.data.history.datahandlers.idatahandler -
# WARNING - ETH/USDT:USDT, futures, 5m, data ends at 2024-12-30 23:55:00
# 2025-09-23 02:58:53,405 - freqtrade.optimize.backtesting - INFO - Loading data
# from 2024-09-01 00:00:00 up to 2024-12-30 23:55:00 (120 days).
# 2025-09-23 02:58:53,405 - freqtrade.configuration.timerange - WARNING - Moving
# start-date by 50 candles to account for startup time.
# 2025-09-23 02:58:53,680 - freqtrade.optimize.backtesting - INFO - Dataload
# complete. Calculating indicators
# 2025-09-23 02:58:53,683 - freqtrade.optimize.backtesting - INFO - Running
# backtesting for Strategy DoubleMAStrategy
# 2025-09-23 02:58:53,683 - freqtrade.strategy.hyper - INFO - Strategy Parameter:
# fast_ma_period = 35
# 2025-09-23 02:58:53,683 - freqtrade.strategy.hyper - INFO - Strategy Parameter:
# ma_type = SMA
# 2025-09-23 02:58:53,683 - freqtrade.strategy.hyper - INFO - Strategy Parameter:
# min_volume_multiplier = 1.53
# 2025-09-23 02:58:53,684 - freqtrade.strategy.hyper - INFO - Strategy Parameter:
# slow_ma_period = 45
# 2025-09-23 02:58:53,684 - freqtrade.strategy.hyper - INFO - Strategy Parameter:
# trend_filter_period = 142
# 2025-09-23 02:58:53,684 - freqtrade.strategy.hyper - INFO - No params for sell
# found, using default values.
# 2025-09-23 02:58:53,684 - freqtrade.strategy.hyper - INFO - No params for
# protection found, using default values.
# 2025-09-23 02:58:53,697 - freqtrade.optimize.backtesting - INFO - Backtesting
# with data from 2024-09-01 04:10:00 up to 2024-12-30 23:55:00 (120 days).
# 2025-09-23 02:58:54,269 - freqtrade.misc - INFO - dumping json to
# "/freqtrade/user_data/backtest_results/backtest-result-2025-09-23_02-58-54.meta.
# json"
# Result for strategy DoubleMAStrategy
#                                BACKTESTING REPORT
# ┏━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃           ┃        ┃           ┃      Tot ┃           ┃          ┃ Win  Draw ┃
# ┃           ┃        ┃       Avg ┃   Profit ┃       Tot ┃      Avg ┃      Loss ┃
# ┃      Pair ┃ Trades ┃  Profit % ┃     USDT ┃  Profit % ┃ Duration ┃      Win% ┃
# ┡━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━┩
# │ ETH/USDT… │     60 │      0.04 │    2.184 │      0.22 │  2:21:00 │        18 │
# │           │        │           │          │           │          │   0    42 │
# │           │        │           │          │           │          │      30.0 │
# │ BTC/USDT… │     67 │     -0.01 │   -2.360 │     -0.24 │  2:04:00 │        18 │
# │           │        │           │          │           │          │   0    49 │
# │           │        │           │          │           │          │      26.9 │
# │     TOTAL │    127 │      0.01 │   -0.176 │     -0.02 │  2:12:00 │        36 │
# │           │        │           │          │           │          │   0    91 │
# │           │        │           │          │           │          │      28.3 │
# └───────────┴────────┴───────────┴──────────┴───────────┴──────────┴───────────┘
#                             LEFT OPEN TRADES REPORT
# ┏━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃       ┃        ┃           ┃            ┃           ┃            ┃ Win  Draw ┃
# ┃       ┃        ┃       Avg ┃ Tot Profit ┃       Tot ┃        Avg ┃      Loss ┃
# ┃  Pair ┃ Trades ┃  Profit % ┃       USDT ┃  Profit % ┃   Duration ┃      Win% ┃
# ┡━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ TOTAL │      0 │       0.0 │      0.000 │       0.0 │       0:00 │         0 │
# │       │        │           │            │           │            │   0     0 │
# │       │        │           │            │           │            │         0 │
# └───────┴────────┴───────────┴────────────┴───────────┴────────────┴───────────┘
#                                 ENTER TAG STATS
# ┏━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┓
# ┃           ┃         ┃          ┃           ┃          ┃           ┃      Win ┃
# ┃           ┃         ┃          ┃       Tot ┃          ┃           ┃     Draw ┃
# ┃           ┃         ┃      Avg ┃    Profit ┃      Tot ┃       Avg ┃     Loss ┃
# ┃ Enter Tag ┃ Entries ┃ Profit % ┃      USDT ┃ Profit % ┃  Duration ┃     Win% ┃
# ┡━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━┩
# │     OTHER │     127 │     0.01 │    -0.176 │    -0.02 │   2:12:00 │       36 │
# │           │         │          │           │          │           │  0    91 │
# │           │         │          │           │          │           │     28.3 │
# │     TOTAL │     127 │     0.01 │    -0.176 │    -0.02 │   2:12:00 │       36 │
# │           │         │          │           │          │           │  0    91 │
# │           │         │          │           │          │           │     28.3 │
# └───────────┴─────────┴──────────┴───────────┴──────────┴───────────┴──────────┘
#                                EXIT REASON STATS
# ┏━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┓
# ┃           ┃       ┃           ┃           ┃           ┃           ┃      Win ┃
# ┃           ┃       ┃           ┃       Tot ┃           ┃           ┃     Draw ┃
# ┃      Exit ┃       ┃       Avg ┃    Profit ┃       Tot ┃       Avg ┃     Loss ┃
# ┃    Reason ┃ Exits ┃  Profit % ┃      USDT ┃  Profit % ┃  Duration ┃     Win% ┃
# ┡━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━┩
# │ exit_sig… │   127 │      0.01 │    -0.176 │     -0.02 │   2:12:00 │       36 │
# │           │       │           │           │           │           │  0    91 │
# │           │       │           │           │           │           │     28.3 │
# │     TOTAL │   127 │      0.01 │    -0.176 │     -0.02 │   2:12:00 │       36 │
# │           │       │           │           │           │           │  0    91 │
# │           │       │           │           │           │           │     28.3 │
# └───────────┴───────┴───────────┴───────────┴───────────┴───────────┴──────────┘
#                                 MIXED TAG STATS
# ┏━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┓
# ┃         ┃         ┃        ┃         ┃         ┃         ┃         ┃     Win ┃
# ┃         ┃         ┃        ┃     Avg ┃     Tot ┃     Tot ┃         ┃    Draw ┃
# ┃   Enter ┃    Exit ┃        ┃  Profit ┃  Profit ┃  Profit ┃     Avg ┃    Loss ┃
# ┃     Tag ┃  Reason ┃ Trades ┃       % ┃    USDT ┃       % ┃ Durati… ┃    Win% ┃
# ┡━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━┩
# │         │ exit_s… │    127 │    0.01 │  -0.176 │   -0.02 │ 2:12:00 │      36 │
# │         │         │        │         │         │         │         │ 0    91 │
# │         │         │        │         │         │         │         │    28.3 │
# │   TOTAL │         │    127 │    0.01 │  -0.176 │   -0.02 │ 2:12:00 │      36 │
# │         │         │        │         │         │         │         │ 0    91 │
# │         │         │        │         │         │         │         │    28.3 │
# └─────────┴─────────┴────────┴─────────┴─────────┴─────────┴─────────┴─────────┘
#                          SUMMARY METRICS
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metric                        ┃ Value                          ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Backtesting from              │ 2024-09-01 04:10:00            │
# │ Backtesting to                │ 2024-12-30 23:55:00            │
# │ Trading Mode                  │ Isolated Futures               │
# │ Max open trades               │ 2                              │
# │                               │                                │
# │ Total/Daily Avg Trades        │ 127 / 1.06                     │
# │ Starting balance              │ 1000 USDT                      │
# │ Final balance                 │ 999.824 USDT                   │
# │ Absolute profit               │ -0.176 USDT                    │
# │ Total profit %                │ -0.02%                         │
# │ CAGR %                        │ -0.05%                         │
# │ Sortino                       │ -0.09                          │
# │ Sharpe                        │ -0.03                          │
# │ Calmar                        │ -0.28                          │
# │ SQN                           │ -0.02                          │
# │ Profit factor                 │ 0.99                           │
# │ Expectancy (Ratio)            │ -0.00 (-0.00)                  │
# │ Avg. daily profit             │ -0.001 USDT                    │
# │ Avg. stake amount             │ 89.205 USDT                    │
# │ Total trade volume            │ 22680.839 USDT                 │
# │                               │                                │
# │ Best Pair                     │ ETH/USDT:USDT 0.22%            │
# │ Worst Pair                    │ BTC/USDT:USDT -0.24%           │
# │ Best trade                    │ ETH/USDT:USDT 6.10%            │
# │ Worst trade                   │ ETH/USDT:USDT -1.49%           │
# │ Best day                      │ 9.381 USDT                     │
# │ Worst day                     │ -2.319 USDT                    │
# │ Days win/draw/lose            │ 20 / 40 / 54                   │
# │ Min/Max/Avg. Duration Winners │ 0d 03:05 / 0d 08:40 / 0d 04:21 │
# │ Min/Max/Avg. Duration Losers  │ 0d 00:05 / 0d 03:55 / 0d 01:20 │
# │ Max Consecutive Wins / Loss   │ 3 / 8                          │
# │ Rejected Entry signals        │ 0                              │
# │ Entry/Exit Timeouts           │ 0 / 0                          │
# │                               │                                │
# │ Min balance                   │ 995.016 USDT                   │
# │ Max balance                   │ 1009.742 USDT                  │
# │ Max % of account underwater   │ 0.98%                          │
# │ Absolute drawdown             │ 9.918 USDT (0.98%)             │
# │ Drawdown duration             │ 43 days 13:15:00               │
# │ Profit at drawdown start      │ 9.742 USDT                     │
# │ Profit at drawdown end        │ -0.176 USDT                    │
# │ Drawdown start                │ 2024-11-11 22:30:00            │
# │ Drawdown end                  │ 2024-12-25 11:45:00            │
# │ Market change                 │ 46.96%                         │
# └───────────────────────────────┴────────────────────────────────┘
#
# Backtested 2024-09-01 04:10:00 -> 2024-12-30 23:55:00 | Max open trades : 2
#                                 STRATEGY SUMMARY
# ┏━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┓
# ┃         ┃        ┃         ┃         ┃         ┃         ┃     Win ┃         ┃
# ┃         ┃        ┃     Avg ┃     Tot ┃     Tot ┃         ┃    Draw ┃         ┃
# ┃         ┃        ┃  Profit ┃  Profit ┃  Profit ┃     Avg ┃    Loss ┃         ┃
# ┃ Strate… ┃ Trades ┃       % ┃    USDT ┃       % ┃ Durati… ┃    Win% ┃ Drawdo… ┃
# ┡━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━┩
# │ Double… │    127 │    0.01 │  -0.176 │   -0.02 │ 2:12:00 │      36 │   9.918 │
# │         │        │         │         │         │         │ 0    91 │    USDT │
# │         │        │         │         │         │         │    28.3 │   0.98% │
# └─────────┴────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┘

# %% [markdown]
# ## 3. Trade

# %%
# !docker compose run --rm freqtrade trade \
  --config /freqtrade/user_data/config_ichiV1.json \
  --strategy ichiV1 \
  --dry-run
# Out:
# 2025-09-23 05:27:02,454 - freqtrade - INFO - freqtrade
# docker-2025.9-dev-f6e1442f
# 2025-09-23 05:27:03,135 - numexpr.utils - INFO - NumExpr defaulting to 10
# threads.
# 2025-09-23 05:27:04,579 - freqtrade.worker - INFO - Starting worker
# docker-2025.9-dev-f6e1442f
# 2025-09-23 05:27:04,580 - freqtrade.configuration.load_config - INFO - Using
# config: /freqtrade/user_data/config_ichiV1.json ...
# 2025-09-23 05:27:04,582 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__JWT_SECRET_KEY'
# 2025-09-23 05:27:04,582 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'JWT_SECRET_KEY']
# 2025-09-23 05:27:04,582 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__LISTEN_IP_ADDRESS'
# 2025-09-23 05:27:04,583 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'LISTEN_IP_ADDRESS']
# 2025-09-23 05:27:04,583 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__LISTEN_PORT'
# 2025-09-23 05:27:04,583 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'LISTEN_PORT']
# 2025-09-23 05:27:04,583 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__WS_TOKEN'
# 2025-09-23 05:27:04,583 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'WS_TOKEN']
# 2025-09-23 05:27:04,584 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__EXCHANGE__KEY'
# 2025-09-23 05:27:04,584 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['EXCHANGE', 'KEY']
# 2025-09-23 05:27:04,584 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__EXCHANGE__SECRET'
# 2025-09-23 05:27:04,584 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['EXCHANGE', 'SECRET']
# 2025-09-23 05:27:04,584 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__TELEGRAM__CHAT_ID'
# 2025-09-23 05:27:04,585 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['TELEGRAM', 'CHAT_ID']
# 2025-09-23 05:27:04,585 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__TELEGRAM__TOKEN'
# 2025-09-23 05:27:04,585 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['TELEGRAM', 'TOKEN']
# 2025-09-23 05:27:04,586 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__WEBHOOK__URL'
# 2025-09-23 05:27:04,586 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['WEBHOOK', 'URL']
# 2025-09-23 05:27:04,588 - freqtrade.loggers - INFO - Enabling colorized output.
# 2025-09-23 05:27:04,588 - freqtrade.loggers - INFO - Logfile configured
# 2025-09-23 05:27:04,588 - freqtrade.loggers - INFO - Verbosity set to 0
# 2025-09-23 05:27:04,589 - freqtrade.configuration.configuration - INFO -
# Parameter --dry-run detected, overriding dry_run to: True ...
# 2025-09-23 05:27:04,589 - freqtrade.configuration.configuration - INFO - Runmode
# set to dry_run.
# 2025-09-23 05:27:04,589 - freqtrade.configuration.configuration - WARNING -
# `force_entry_enable` RPC message enabled.
# 2025-09-23 05:27:04,590 - freqtrade.configuration.configuration - INFO - Dry run
# is enabled
# 2025-09-23 05:27:04,590 - freqtrade.configuration.configuration - INFO - Using
# DB: "sqlite:///tradesv3.dryrun.sqlite"
# 2025-09-23 05:27:04,590 - freqtrade.configuration.configuration - INFO - Using
# max_open_trades: 5 ...
# 2025-09-23 05:27:04,663 - freqtrade.configuration.configuration - INFO - Using
# user-data directory: /freqtrade/user_data ...
# 2025-09-23 05:27:04,664 - freqtrade.configuration.configuration - INFO - Using
# data directory: /freqtrade/user_data/data/binance ...
# 2025-09-23 05:27:04,665 - freqtrade.exchange.check_exchange - INFO - Checking
# exchange...
# 2025-09-23 05:27:04,674 - freqtrade.exchange.check_exchange - INFO - Exchange
# "binance" is officially supported by the Freqtrade development team.
# 2025-09-23 05:27:04,674 - freqtrade.configuration.configuration - INFO - Using
# pairlist from configuration.
# 2025-09-23 05:27:04,675 - freqtrade.exchange.exchange - INFO - Instance is
# running with dry_run enabled
# 2025-09-23 05:27:04,675 - freqtrade.exchange.exchange - INFO - Using CCXT 4.5.4
# 2025-09-23 05:27:04,700 - freqtrade.exchange.exchange - INFO - Using Exchange
# "Binance"
# 2025-09-23 05:27:10,182 - freqtrade.resolvers.exchange_resolver - INFO - Using
# resolved exchange 'Binance'...
# 2025-09-23 05:27:10,215 - freqtrade.resolvers.iresolver - INFO - Using resolved
# strategy ichiV1 from '/freqtrade/user_data/strategies/ichiV1.py'...
# 2025-09-23 05:27:10,216 - freqtrade.strategy.hyper - INFO - Found no parameter
# file.
# 2025-09-23 05:27:10,216 - freqtrade.resolvers.strategy_resolver - WARNING -
# DEPRECATED: Using 'sell_profit_only' moved to 'exit_profit_only'.
# 2025-09-23 05:27:10,217 - freqtrade.resolvers.strategy_resolver - WARNING -
# DEPRECATED: Using 'use_sell_signal' moved to 'use_exit_signal'.
# 2025-09-23 05:27:10,217 - freqtrade.resolvers.strategy_resolver - WARNING -
# DEPRECATED: Using 'ignore_roi_if_buy_signal' moved to
# 'ignore_roi_if_entry_signal'.
# 2025-09-23 05:27:10,218 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'timeframe' with value from the configuration: 5m.
# 2025-09-23 05:27:10,219 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'stake_currency' with value from the configuration: USDT.
# 2025-09-23 05:27:10,219 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'stake_amount' with value from the configuration: 20.
# 2025-09-23 05:27:10,219 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'unfilledtimeout' with value from the configuration: {'entry':
# 10, 'exit': 10, 'exit_timeout_count': 0, 'unit': 'minutes'}.
# 2025-09-23 05:27:10,219 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'max_open_trades' with value from the configuration: 5.
# 2025-09-23 05:27:10,219 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using minimal_roi: {'0': 0.059, '10': 0.037, '41': 0.012, '114': 0}
# 2025-09-23 05:27:10,220 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using timeframe: 5m
# 2025-09-23 05:27:10,220 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stoploss: -0.275
# 2025-09-23 05:27:10,220 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_stop: False
# 2025-09-23 05:27:10,220 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_stop_positive_offset: 0.0
# 2025-09-23 05:27:10,220 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_only_offset_is_reached: False
# 2025-09-23 05:27:10,221 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using use_custom_stoploss: False
# 2025-09-23 05:27:10,221 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using process_only_new_candles: False
# 2025-09-23 05:27:10,221 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using order_types: {'entry': 'limit', 'exit': 'limit', 'stoploss':
# 'limit', 'stoploss_on_exchange': False, 'stoploss_on_exchange_interval': 60}
# 2025-09-23 05:27:10,222 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using order_time_in_force: {'entry': 'GTC', 'exit': 'GTC'}
# 2025-09-23 05:27:10,222 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stake_currency: USDT
# 2025-09-23 05:27:10,222 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stake_amount: 20
# 2025-09-23 05:27:10,222 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using startup_candle_count: 96
# 2025-09-23 05:27:10,222 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using unfilledtimeout: {'entry': 10, 'exit': 10, 'exit_timeout_count':
# 0, 'unit': 'minutes'}
# 2025-09-23 05:27:10,223 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using use_exit_signal: True
# 2025-09-23 05:27:10,223 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using exit_profit_only: False
# 2025-09-23 05:27:10,223 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using ignore_roi_if_entry_signal: False
# 2025-09-23 05:27:10,223 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using exit_profit_offset: 0.0
# 2025-09-23 05:27:10,224 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using disable_dataframe_checks: False
# 2025-09-23 05:27:10,224 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using ignore_buying_expired_candle_after: 0
# 2025-09-23 05:27:10,224 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using position_adjustment_enable: False
# 2025-09-23 05:27:10,224 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using max_entry_position_adjustment: -1
# 2025-09-23 05:27:10,225 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using max_open_trades: 5
# 2025-09-23 05:27:10,225 - freqtrade.configuration.config_validation - INFO -
# Validating configuration ...
# 2025-09-23 05:27:10,280 - freqtrade.wallets - INFO - Wallets synced.
# 2025-09-23 05:27:11,605 - freqtrade.rpc.rpc_manager - INFO - Enabling
# rpc.webhook ...
# 2025-09-23 05:27:11,608 - freqtrade.rpc.rpc_manager - INFO - Enabling
# rpc.api_server
# 2025-09-23 05:27:11,753 - freqtrade.rpc.api_server.webserver - INFO - Starting
# HTTP Server at 0.0.0.0:8080
# 2025-09-23 05:27:11,754 - freqtrade.rpc.api_server.webserver - INFO - Starting
# Local Rest Server.
# 2025-09-23 05:27:11,778 - uvicorn.error - INFO - Started server process [1]
# 2025-09-23 05:27:11,779 - uvicorn.error - INFO - Waiting for application
# startup.
# 2025-09-23 05:27:11,780 - uvicorn.error - INFO - Application startup complete.
# 2025-09-23 05:27:11,780 - uvicorn.error - INFO - Uvicorn running on
# http://0.0.0.0:8080 (Press CTRL+C to quit)
# 2025-09-23 05:27:11,798 - freqtrade.resolvers.iresolver - INFO - Using resolved
# pairlist StaticPairList from
# '/freqtrade/freqtrade/plugins/pairlist/StaticPairList.py'...
# 2025-09-23 05:27:11,799 - freqtrade.freqtradebot - INFO - Starting initial
# pairlist refresh
# 2025-09-23 05:27:11,836 - freqtrade.plugins.pairlistmanager - INFO - Whitelist
# with 4 pairs: ['BTC/USDT', 'ETC/USDT', 'BNB/USDT', 'DOGE/USDT']
# 2025-09-23 05:27:11,837 - freqtrade.freqtradebot - INFO - Initial Pairlist
# refresh took 0.04s
# 2025-09-23 05:27:11,838 - freqtrade.strategy.hyper - INFO - No params for
# protection found, using default values.
# 2025-09-23 05:27:11,838 - freqtrade.plugins.protectionmanager - INFO - No
# protection Handlers defined.
# 2025-09-23 05:27:11,839 - freqtrade.rpc.rpc_manager - INFO - Sending rpc
# message: {'type': status, 'status': 'running'}
# 2025-09-23 05:27:12,572 - freqtrade.worker - INFO - Changing state to: RUNNING
# 2025-09-23 05:27:12,588 - freqtrade.rpc.rpc_manager - INFO - Sending rpc
# message: {'type': warning, 'status': 'Dry run is enabled. All trades are
# simulated.'}
# 2025-09-23 05:27:13,163 - freqtrade.rpc.rpc_manager - INFO - Sending rpc
# message: {'type': startup, 'status': "*Exchange:* `binance`\n*Stake per trade:*
# `20 USDT`\n*Minimum ROI:* `{'0': 0.059, '10': 0.037, '41': 0.012, '114':
# 0}`\n*Stoploss:* `-0.275`\n*Position adjustment:* `Off`\n*Timeframe:*
# `5m`\n*Strategy:* `ichiV1`"}
# 2025-09-23 05:27:13,737 - freqtrade.rpc.rpc_manager - INFO - Sending rpc
# message: {'type': startup, 'status': "Searching for USDT pairs to buy and sell
# based on [{'StaticPairList': 'StaticPairList'}]"}
# 2025-09-23 05:27:19,351 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:28:19,393 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:29:19,435 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:30:21,014 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:31:21,053 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:32:21,095 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:33:21,137 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:34:21,170 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:35:26,024 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:36:26,062 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:37:26,104 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:38:26,153 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:39:26,198 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:40:31,025 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:41:31,069 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:42:31,113 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:43:31,166 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:44:31,204 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:45:36,021 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:46:36,058 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:47:36,107 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:48:36,155 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:49:36,213 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 05:49:54,594 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for ETC/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Connection closed by remote server, closing code
# 1006
# 2025-09-23 05:49:54,607 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for DOGE/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Connection closed by remote server, closing code
# 1006
# 2025-09-23 05:49:54,608 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for BTC/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Connection closed by remote server, closing code
# 1006
# 2025-09-23 05:49:54,610 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for BNB/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Connection closed by remote server, closing code
# 1006
# 2025-09-23 05:49:54,611 - freqtrade.exchange.exchange_ws - INFO - ETC/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 05:49:54,612 - freqtrade.exchange.exchange_ws - INFO - DOGE/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 05:49:54,612 - freqtrade.exchange.exchange_ws - INFO - BTC/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 05:49:54,613 - freqtrade.exchange.exchange_ws - INFO - BNB/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 05:50:00,635 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:00,642 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:00,647 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:00,652 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:01,081 - freqtrade.exchange.exchange - INFO - Couldn't reuse
# watch for ETC/USDT, 5m, falling back to REST api. False, 1758606600000, 0,
# 2025-09-23T05:50:00, 1970-01-01T00:00:00
# 2025-09-23 05:50:01,083 - freqtrade.exchange.exchange - INFO - Couldn't reuse
# watch for BNB/USDT, 5m, falling back to REST api. False, 1758606600000, 0,
# 2025-09-23T05:50:00, 1970-01-01T00:00:00
# 2025-09-23 05:50:01,083 - freqtrade.exchange.exchange - INFO - Couldn't reuse
# watch for DOGE/USDT, 5m, falling back to REST api. False, 1758606600000, 0,
# 2025-09-23T05:50:00, 1970-01-01T00:00:00
# 2025-09-23 05:50:01,084 - freqtrade.exchange.exchange - INFO - Couldn't reuse
# watch for BTC/USDT, 5m, falling back to REST api. False, 1758606600000, 0,
# 2025-09-23T05:50:00, 1970-01-01T00:00:00
# 2025-09-23 05:50:02,678 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for DOGE/USDT, 5m, spot due to ExchangeNotAvailable.
# Message: binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=DOGEUSDT".
# Retrying still for 4 times.
# 2025-09-23 05:50:02,679 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BNB/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BNBUSDT".
# Retrying still for 4 times.
# 2025-09-23 05:50:02,679 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BTC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BTCUSDT".
# Retrying still for 4 times.
# 2025-09-23 05:50:02,680 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for ETC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=ETCUSDT".
# Retrying still for 4 times.
# 2025-09-23 05:50:06,402 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for ETC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=ETCUSDT".
# Retrying still for 3 times.
# 2025-09-23 05:50:06,403 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BTC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BTCUSDT".
# Retrying still for 3 times.
# 2025-09-23 05:50:06,406 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BNB/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BNBUSDT".
# Retrying still for 3 times.
# 2025-09-23 05:50:06,407 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for DOGE/USDT, 5m, spot due to ExchangeNotAvailable.
# Message: binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=DOGEUSDT".
# Retrying still for 3 times.
# 2025-09-23 05:50:07,094 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for ETC/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:07,099 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for BNB/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:07,101 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for DOGE/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:07,103 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for BTC/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:07,104 - freqtrade.exchange.exchange_ws - INFO - ETC/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 05:50:07,105 - freqtrade.exchange.exchange_ws - INFO - BNB/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 05:50:07,107 - freqtrade.exchange.exchange_ws - INFO - DOGE/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 05:50:07,108 - freqtrade.exchange.exchange_ws - INFO - BTC/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 05:50:07,718 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for DOGE/USDT, 5m, spot due to ExchangeNotAvailable.
# Message: binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=DOGEUSDT".
# Retrying still for 2 times.
# 2025-09-23 05:50:07,720 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BTC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BTCUSDT".
# Retrying still for 2 times.
# 2025-09-23 05:50:07,722 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BNB/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BNBUSDT".
# Retrying still for 2 times.
# 2025-09-23 05:50:07,723 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for ETC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=ETCUSDT".
# Retrying still for 2 times.
# 2025-09-23 05:50:10,362 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BTC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BTCUSDT".
# Retrying still for 1 times.
# 2025-09-23 05:50:10,365 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BNB/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BNBUSDT".
# Retrying still for 1 times.
# 2025-09-23 05:50:10,366 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for ETC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=ETCUSDT".
# Retrying still for 1 times.
# 2025-09-23 05:50:10,368 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for DOGE/USDT, 5m, spot due to ExchangeNotAvailable.
# Message: binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=DOGEUSDT".
# Retrying still for 1 times.
# 2025-09-23 05:50:11,683 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BNB/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BNBUSDT".
# Giving up.
# 2025-09-23 05:50:11,684 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for ETC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=ETCUSDT".
# Giving up.
# 2025-09-23 05:50:11,685 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for DOGE/USDT, 5m, spot due to ExchangeNotAvailable.
# Message: binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=DOGEUSDT".
# Giving up.
# 2025-09-23 05:50:11,686 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BTC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BTCUSDT".
# Giving up.
# 2025-09-23 05:50:11,688 - freqtrade.exchange.exchange - WARNING - Async code
# raised an exception: TemporaryError('Could not fetch historical candle (OHLCV)
# data for ETC/USDT, 5m, spot due to ExchangeNotAvailable. Message: binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=ETCUSDT')
# 2025-09-23 05:50:11,692 - freqtrade.exchange.exchange - WARNING - Async code
# raised an exception: TemporaryError('Could not fetch historical candle (OHLCV)
# data for BNB/USDT, 5m, spot due to ExchangeNotAvailable. Message: binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BNBUSDT')
# 2025-09-23 05:50:11,692 - freqtrade.exchange.exchange - WARNING - Async code
# raised an exception: TemporaryError('Could not fetch historical candle (OHLCV)
# data for DOGE/USDT, 5m, spot due to ExchangeNotAvailable. Message: binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=DOGEUSDT')
# 2025-09-23 05:50:11,692 - freqtrade.exchange.exchange - WARNING - Async code
# raised an exception: TemporaryError('Could not fetch historical candle (OHLCV)
# data for BTC/USDT, 5m, spot due to ExchangeNotAvailable. Message: binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BTCUSDT')
# 2025-09-23 05:50:11,905 - freqtrade.exchange.exchange - INFO - Couldn't reuse
# watch for ETC/USDT, 5m, falling back to REST api. False, 1758606600000, 0,
# 2025-09-23T05:50:00, 1970-01-01T00:00:00
# 2025-09-23 05:50:11,906 - freqtrade.exchange.exchange - INFO - Couldn't reuse
# watch for BNB/USDT, 5m, falling back to REST api. False, 1758606600000, 0,
# 2025-09-23T05:50:00, 1970-01-01T00:00:00
# 2025-09-23 05:50:11,906 - freqtrade.exchange.exchange - INFO - Couldn't reuse
# watch for DOGE/USDT, 5m, falling back to REST api. False, 1758606600000, 0,
# 2025-09-23T05:50:00, 1970-01-01T00:00:00
# 2025-09-23 05:50:11,907 - freqtrade.exchange.exchange - INFO - Couldn't reuse
# watch for BTC/USDT, 5m, falling back to REST api. False, 1758606600000, 0,
# 2025-09-23T05:50:00, 1970-01-01T00:00:00
# 2025-09-23 05:50:13,090 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for DOGE/USDT, 5m, spot due to ExchangeNotAvailable.
# Message: binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=DOGEUSDT".
# Retrying still for 4 times.
# 2025-09-23 05:50:13,092 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BTC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BTCUSDT".
# Retrying still for 4 times.
# 2025-09-23 05:50:13,093 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BNB/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BNBUSDT".
# Retrying still for 4 times.
# 2025-09-23 05:50:13,094 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for ETC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=ETCUSDT".
# Retrying still for 4 times.
# 2025-09-23 05:50:13,119 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:13,125 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:13,127 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:13,129 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:13,131 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for ETC/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:13,134 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for DOGE/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:13,135 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for BNB/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:13,137 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for BTC/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.NetworkError: Cannot connect to host stream.binance.com:9443
# ssl:default [DNS server returned general failure]
# 2025-09-23 05:50:13,140 - freqtrade.exchange.exchange_ws - INFO - ETC/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 05:50:13,140 - freqtrade.exchange.exchange_ws - INFO - DOGE/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 05:50:13,141 - freqtrade.exchange.exchange_ws - INFO - BNB/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 05:50:13,141 - freqtrade.exchange.exchange_ws - INFO - BTC/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 05:50:17,007 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for ETC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=ETCUSDT".
# Retrying still for 3 times.
# 2025-09-23 05:50:17,009 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BTC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BTCUSDT".
# Retrying still for 3 times.
# 2025-09-23 05:50:17,010 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# ...
# 2025-09-23 10:56:20,885 - freqtrade.strategy.interface - WARNING - Outdated
# history for pair BNB/USDT. Last tick is 16 minutes old
# 2025-09-23 10:56:20,886 - freqtrade.strategy.interface - WARNING - Outdated
# history for pair DOGE/USDT. Last tick is 16 minutes old
# 2025-09-23 10:56:20,929 - freqtrade.exchange.exchange - INFO - Couldn't reuse
# watch for ETC/USDT, 5m, falling back to REST api. False, 1758624900000, 0,
# 2025-09-23T10:55:00, 1970-01-01T00:00:00
# 2025-09-23 10:56:20,930 - freqtrade.exchange.exchange - INFO - Couldn't reuse
# watch for BNB/USDT, 5m, falling back to REST api. False, 1758624900000, 0,
# 2025-09-23T10:55:00, 1970-01-01T00:00:00
# 2025-09-23 10:56:20,931 - freqtrade.exchange.exchange - INFO - Couldn't reuse
# watch for DOGE/USDT, 5m, falling back to REST api. False, 1758624900000, 0,
# 2025-09-23T10:55:00, 1970-01-01T00:00:00
# 2025-09-23 10:56:20,931 - freqtrade.exchange.exchange - INFO - Couldn't reuse
# watch for BTC/USDT, 5m, falling back to REST api. False, 1758624900000, 0,
# 2025-09-23T10:55:00, 1970-01-01T00:00:00
# 2025-09-23 10:56:22,303 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BTC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BTCUSDT".
# Retrying still for 4 times.
# 2025-09-23 10:56:22,305 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BNB/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BNBUSDT".
# Retrying still for 4 times.
# 2025-09-23 10:56:22,306 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for DOGE/USDT, 5m, spot due to ExchangeNotAvailable.
# Message: binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=DOGEUSDT".
# Retrying still for 4 times.
# 2025-09-23 10:56:22,307 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for ETC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=ETCUSDT".
# Retrying still for 4 times.
# 2025-09-23 10:56:22,791 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.RequestTimeout: Connection timeout
# 2025-09-23 10:56:22,794 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.RequestTimeout: Connection timeout
# 2025-09-23 10:56:22,796 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.RequestTimeout: Connection timeout
# 2025-09-23 10:56:22,798 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.RequestTimeout: Connection timeout
# 2025-09-23 10:56:22,799 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for ETC/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.RequestTimeout: Connection timeout
# 2025-09-23 10:56:22,801 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for DOGE/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.RequestTimeout: Connection timeout
# 2025-09-23 10:56:22,802 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for BNB/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.RequestTimeout: Connection timeout
# 2025-09-23 10:56:22,803 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# continuously_async_watch_ohlcv for BTC/USDT, 5m
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 176, in
# _continuously_async_watch_ohlcv
#     data = await self._ccxt_object.watch_ohlcv(pair, timeframe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1328, in watch_ohlcv
#     result = await self.watch_ohlcv_for_symbols([[symbol, timeframe]], since,
# limit, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1387, in watch_ohlcv_for_symbols
#     symbol, timeframe, candles = await self.watch_multiple(url, messageHashes,
# self.extend(request, params), messageHashes, subscribe)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.RequestTimeout: Connection timeout
# 2025-09-23 10:56:22,804 - freqtrade.exchange.exchange_ws - INFO - ETC/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 10:56:22,804 - freqtrade.exchange.exchange_ws - INFO - DOGE/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 10:56:22,804 - freqtrade.exchange.exchange_ws - INFO - BNB/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 10:56:22,806 - freqtrade.exchange.exchange_ws - INFO - BTC/USDT, 5m,
# spot - Task finished - done
# 2025-09-23 10:56:26,063 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BNB/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BNBUSDT".
# Retrying still for 3 times.
# 2025-09-23 10:56:26,066 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for ETC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=ETCUSDT".
# Retrying still for 3 times.
# 2025-09-23 10:56:26,068 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for DOGE/USDT, 5m, spot due to ExchangeNotAvailable.
# Message: binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=DOGEUSDT".
# Retrying still for 3 times.
# 2025-09-23 10:56:26,069 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BTC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BTCUSDT".
# Retrying still for 3 times.
# 2025-09-23 10:56:27,648 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for DOGE/USDT, 5m, spot due to ExchangeNotAvailable.
# Message: binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=DOGEUSDT".
# Retrying still for 2 times.
# 2025-09-23 10:56:27,650 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for ETC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=ETCUSDT".
# Retrying still for 2 times.
# 2025-09-23 10:56:27,651 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BTC/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BTCUSDT".
# Retrying still for 2 times.
# 2025-09-23 10:56:27,652 - freqtrade.exchange.common - WARNING -
# _async_get_candle_history() returned exception: "Could not fetch historical
# candle (OHLCV) data for BNB/USDT, 5m, spot due to ExchangeNotAvailable. Message:
# binance GET
# https://api.binance.com/api/v3/klines?interval=5m&limit=1000&symbol=BNBUSDT".
# Retrying still for 2 times.
# 2025-09-23 10:56:32,823 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.RequestTimeout: Connection timeout
# 2025-09-23 10:56:32,826 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.RequestTimeout: Connection timeout
# 2025-09-23 10:56:32,828 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.RequestTimeout: Connection timeout
# 2025-09-23 10:56:32,831 - freqtrade.exchange.exchange_ws - ERROR - Exception in
# _unwatch_ohlcv
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/exchange/exchange_ws.py", line 144, in
# _unwatch_ohlcv
#     await self._ccxt_object.un_watch_ohlcv_for_symbols([[pair, timeframe]])
#   File "/home/ftuser/.local/lib/python3.13/site-packages/ccxt/pro/binance.py",
# line 1455, in un_watch_ohlcv_for_symbols
#     return await self.watch_multiple(url, messageHashes, self.extend(request,
# params), messageHashes, subscribe)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ccxt.base.errors.RequestTimeout: Connection timeout
# ^C
# 2025-09-23 10:56:33,187 - freqtrade.commands.trade_commands - INFO - worker
# found ... calling exit
# 2025-09-23 10:56:33,188 - freqtrade.rpc.rpc_manager - INFO - Sending rpc
# message: {'type': status, 'status': 'process died'}
# 2025-09-23 10:56:33,192 - freqtrade - INFO - SIGINT received, aborting ...

# %%
# !docker compose run --rm freqtrade trade \
  --config /freqtrade/user_data/config_ichiV1.json \
  --strategy ichiV1 \
  ## 手动在配置里改 --trading-mode futures \
  --dry-run
# Out:
# 2025-09-23 10:56:46,316 - freqtrade - INFO - freqtrade
# docker-2025.9-dev-f6e1442f
# 2025-09-23 10:56:46,891 - numexpr.utils - INFO - NumExpr defaulting to 10
# threads.
# 2025-09-23 10:56:48,537 - freqtrade.worker - INFO - Starting worker
# docker-2025.9-dev-f6e1442f
# 2025-09-23 10:56:48,537 - freqtrade.configuration.load_config - INFO - Using
# config: /freqtrade/user_data/config_ichiV1.json ...
# 2025-09-23 10:56:48,541 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__JWT_SECRET_KEY'
# 2025-09-23 10:56:48,541 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'JWT_SECRET_KEY']
# 2025-09-23 10:56:48,542 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__LISTEN_IP_ADDRESS'
# 2025-09-23 10:56:48,542 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'LISTEN_IP_ADDRESS']
# 2025-09-23 10:56:48,542 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__LISTEN_PORT'
# 2025-09-23 10:56:48,543 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'LISTEN_PORT']
# 2025-09-23 10:56:48,543 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__WS_TOKEN'
# 2025-09-23 10:56:48,543 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'WS_TOKEN']
# 2025-09-23 10:56:48,543 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__EXCHANGE__KEY'
# 2025-09-23 10:56:48,543 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['EXCHANGE', 'KEY']
# 2025-09-23 10:56:48,544 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__EXCHANGE__SECRET'
# 2025-09-23 10:56:48,544 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['EXCHANGE', 'SECRET']
# 2025-09-23 10:56:48,544 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__TELEGRAM__CHAT_ID'
# 2025-09-23 10:56:48,544 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['TELEGRAM', 'CHAT_ID']
# 2025-09-23 10:56:48,545 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__TELEGRAM__TOKEN'
# 2025-09-23 10:56:48,545 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['TELEGRAM', 'TOKEN']
# 2025-09-23 10:56:48,545 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__WEBHOOK__URL'
# 2025-09-23 10:56:48,545 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['WEBHOOK', 'URL']
# 2025-09-23 10:56:48,547 - freqtrade.loggers - INFO - Enabling colorized output.
# 2025-09-23 10:56:48,547 - freqtrade.loggers - INFO - Logfile configured
# 2025-09-23 10:56:48,548 - freqtrade.loggers - INFO - Verbosity set to 0
# 2025-09-23 10:56:48,548 - freqtrade.configuration.configuration - INFO - Runmode
# set to dry_run.
# 2025-09-23 10:56:48,548 - freqtrade.configuration.configuration - WARNING -
# `force_entry_enable` RPC message enabled.
# 2025-09-23 10:56:48,549 - freqtrade.configuration.configuration - INFO - Dry run
# is enabled
# 2025-09-23 10:56:48,549 - freqtrade.configuration.configuration - INFO - Using
# DB: "sqlite:///tradesv3.dryrun.sqlite"
# 2025-09-23 10:56:48,549 - freqtrade.configuration.configuration - INFO - Using
# max_open_trades: 5 ...
# 2025-09-23 10:56:48,621 - freqtrade.configuration.configuration - INFO - Using
# user-data directory: /freqtrade/user_data ...
# 2025-09-23 10:56:48,622 - freqtrade.configuration.configuration - INFO - Using
# data directory: /freqtrade/user_data/data/binance ...
# 2025-09-23 10:56:48,623 - freqtrade.exchange.check_exchange - INFO - Checking
# exchange...
# 2025-09-23 10:56:48,632 - freqtrade.exchange.check_exchange - INFO - Exchange
# "binance" is officially supported by the Freqtrade development team.
# 2025-09-23 10:56:48,633 - freqtrade.configuration.configuration - INFO - Using
# pairlist from configuration.
# 2025-09-23 10:56:48,633 - freqtrade.exchange.exchange - INFO - Instance is
# running with dry_run enabled
# 2025-09-23 10:56:48,634 - freqtrade.exchange.exchange - INFO - Using CCXT 4.5.4
# 2025-09-23 10:56:48,660 - freqtrade.exchange.exchange - INFO - Using Exchange
# "Binance"
# 2025-09-23 10:56:54,759 - freqtrade.resolvers.exchange_resolver - INFO - Using
# resolved exchange 'Binance'...
# 2025-09-23 10:56:54,791 - freqtrade.resolvers.iresolver - INFO - Using resolved
# strategy ichiV1 from '/freqtrade/user_data/strategies/ichiV1.py'...
# 2025-09-23 10:56:54,792 - freqtrade.strategy.hyper - INFO - Found no parameter
# file.
# 2025-09-23 10:56:54,792 - freqtrade.resolvers.strategy_resolver - WARNING -
# DEPRECATED: Using 'sell_profit_only' moved to 'exit_profit_only'.
# 2025-09-23 10:56:54,793 - freqtrade.resolvers.strategy_resolver - WARNING -
# DEPRECATED: Using 'use_sell_signal' moved to 'use_exit_signal'.
# 2025-09-23 10:56:54,793 - freqtrade.resolvers.strategy_resolver - WARNING -
# DEPRECATED: Using 'ignore_roi_if_buy_signal' moved to
# 'ignore_roi_if_entry_signal'.
# 2025-09-23 10:56:54,793 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'timeframe' with value from the configuration: 5m.
# 2025-09-23 10:56:54,794 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'stake_currency' with value from the configuration: USDT.
# 2025-09-23 10:56:54,794 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'stake_amount' with value from the configuration: 20.
# 2025-09-23 10:56:54,794 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'unfilledtimeout' with value from the configuration: {'entry':
# 10, 'exit': 10, 'exit_timeout_count': 0, 'unit': 'minutes'}.
# 2025-09-23 10:56:54,794 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'max_open_trades' with value from the configuration: 5.
# 2025-09-23 10:56:54,795 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using minimal_roi: {'0': 0.059, '10': 0.037, '41': 0.012, '114': 0}
# 2025-09-23 10:56:54,795 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using timeframe: 5m
# 2025-09-23 10:56:54,795 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stoploss: -0.275
# 2025-09-23 10:56:54,795 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_stop: False
# 2025-09-23 10:56:54,795 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_stop_positive_offset: 0.0
# 2025-09-23 10:56:54,796 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_only_offset_is_reached: False
# 2025-09-23 10:56:54,796 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using use_custom_stoploss: False
# 2025-09-23 10:56:54,796 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using process_only_new_candles: False
# 2025-09-23 10:56:54,797 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using order_types: {'entry': 'limit', 'exit': 'limit', 'stoploss':
# 'limit', 'stoploss_on_exchange': False, 'stoploss_on_exchange_interval': 60}
# 2025-09-23 10:56:54,797 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using order_time_in_force: {'entry': 'GTC', 'exit': 'GTC'}
# 2025-09-23 10:56:54,797 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stake_currency: USDT
# 2025-09-23 10:56:54,798 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stake_amount: 20
# 2025-09-23 10:56:54,798 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using startup_candle_count: 96
# 2025-09-23 10:56:54,798 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using unfilledtimeout: {'entry': 10, 'exit': 10, 'exit_timeout_count':
# 0, 'unit': 'minutes'}
# 2025-09-23 10:56:54,798 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using use_exit_signal: True
# 2025-09-23 10:56:54,799 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using exit_profit_only: False
# 2025-09-23 10:56:54,799 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using ignore_roi_if_entry_signal: False
# 2025-09-23 10:56:54,799 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using exit_profit_offset: 0.0
# 2025-09-23 10:56:54,799 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using disable_dataframe_checks: False
# 2025-09-23 10:56:54,799 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using ignore_buying_expired_candle_after: 0
# 2025-09-23 10:56:54,800 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using position_adjustment_enable: False
# 2025-09-23 10:56:54,800 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using max_entry_position_adjustment: -1
# 2025-09-23 10:56:54,800 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using max_open_trades: 5
# 2025-09-23 10:56:54,800 - freqtrade.configuration.config_validation - INFO -
# Validating configuration ...
# 2025-09-23 10:56:54,856 - freqtrade.wallets - INFO - Wallets synced.
# 2025-09-23 10:56:56,200 - freqtrade.rpc.rpc_manager - INFO - Enabling
# rpc.webhook ...
# 2025-09-23 10:56:56,203 - freqtrade.rpc.rpc_manager - INFO - Enabling
# rpc.api_server
# 2025-09-23 10:56:56,338 - freqtrade.rpc.api_server.webserver - INFO - Starting
# HTTP Server at 0.0.0.0:8080
# 2025-09-23 10:56:56,338 - freqtrade.rpc.api_server.webserver - INFO - Starting
# Local Rest Server.
# 2025-09-23 10:56:56,355 - uvicorn.error - INFO - Started server process [1]
# 2025-09-23 10:56:56,355 - uvicorn.error - INFO - Waiting for application
# startup.
# 2025-09-23 10:56:56,356 - uvicorn.error - INFO - Application startup complete.
# 2025-09-23 10:56:56,356 - uvicorn.error - INFO - Uvicorn running on
# http://0.0.0.0:8080 (Press CTRL+C to quit)
# 2025-09-23 10:56:56,373 - freqtrade.resolvers.iresolver - INFO - Using resolved
# pairlist StaticPairList from
# '/freqtrade/freqtrade/plugins/pairlist/StaticPairList.py'...
# 2025-09-23 10:56:56,373 - freqtrade.freqtradebot - INFO - Starting initial
# pairlist refresh
# 2025-09-23 10:56:56,412 - freqtrade.plugins.pairlistmanager - INFO - Whitelist
# with 4 pairs: ['BTC/USDT', 'ETC/USDT', 'BNB/USDT', 'DOGE/USDT']
# 2025-09-23 10:56:56,413 - freqtrade.freqtradebot - INFO - Initial Pairlist
# refresh took 0.04s
# 2025-09-23 10:56:56,413 - freqtrade.strategy.hyper - INFO - No params for
# protection found, using default values.
# 2025-09-23 10:56:56,414 - freqtrade.plugins.protectionmanager - INFO - No
# protection Handlers defined.
# 2025-09-23 10:56:56,414 - freqtrade.rpc.rpc_manager - INFO - Sending rpc
# message: {'type': status, 'status': 'running'}
# 2025-09-23 10:56:57,007 - freqtrade.worker - INFO - Changing state to: RUNNING
# 2025-09-23 10:56:57,021 - freqtrade.rpc.rpc_manager - INFO - Sending rpc
# message: {'type': warning, 'status': 'Dry run is enabled. All trades are
# simulated.'}
# 2025-09-23 10:56:57,570 - freqtrade.rpc.rpc_manager - INFO - Sending rpc
# message: {'type': startup, 'status': "*Exchange:* `binance`\n*Stake per trade:*
# `20 USDT`\n*Minimum ROI:* `{'0': 0.059, '10': 0.037, '41': 0.012, '114':
# 0}`\n*Stoploss:* `-0.275`\n*Position adjustment:* `Off`\n*Timeframe:*
# `5m`\n*Strategy:* `ichiV1`"}
# 2025-09-23 10:56:58,110 - freqtrade.rpc.rpc_manager - INFO - Sending rpc
# message: {'type': startup, 'status': "Searching for USDT pairs to buy and sell
# based on [{'StaticPairList': 'StaticPairList'}]"}
# 2025-09-23 10:57:03,951 - freqtrade.worker - INFO - Bot heartbeat. PID=1,
# version='docker-2025.9-dev-f6e1442f', state='RUNNING'
# 2025-09-23 10:57:04,409 - freqtrade.commands.trade_commands - INFO - worker
# found ... calling exit
# 2025-09-23 10:57:04,410 - freqtrade.rpc.rpc_manager - INFO - Sending rpc
# message: {'type': status, 'status': 'process died'}
# ^C
# 2025-09-23 10:57:04,445 - freqtrade - INFO - SIGINT received, aborting ...

# %% [markdown]
# ## API Call

# %%
# !curl -u freqtrader:123 -H 'Content-Type: application/json' \
  -X POST http://localhost:8080/api/v1/forcebuy \
  -d '{"pair":"BTC/USDT"}'
# Out:
# curl: (7) Failed to connect to localhost port 8080 after 0 ms: Couldn't connect to server

# %% [markdown]
# ## 4. Plot

# %%
# !docker compose run --rm freqtrade plot-dataframe \
  --strategy ichiV1 \
  --config /freqtrade/user_data/config_ichiV1.json \
  --config /freqtrade/user_data/config_plot.json \
  --pairs BTC/USDT --timeframe 5m --timerange 20240101-20240630
# Out:
# 2025-09-24 03:02:36,654 - freqtrade - INFO - freqtrade
# docker-2025.9-dev-f6e1442f
# 2025-09-24 03:02:37,320 - numexpr.utils - INFO - NumExpr defaulting to 10
# threads.
# 2025-09-24 03:02:38,766 - freqtrade.configuration.load_config - INFO - Using
# config: /freqtrade/user_data/config_ichiV1.json ...
# 2025-09-24 03:02:38,781 - freqtrade.configuration.load_config - INFO - Using
# config: /freqtrade/user_data/config_plot.json ...
# 2025-09-24 03:02:38,782 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__JWT_SECRET_KEY'
# 2025-09-24 03:02:38,783 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'JWT_SECRET_KEY']
# 2025-09-24 03:02:38,784 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__LISTEN_IP_ADDRESS'
# 2025-09-24 03:02:38,784 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'LISTEN_IP_ADDRESS']
# 2025-09-24 03:02:38,785 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__LISTEN_PORT'
# 2025-09-24 03:02:38,785 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'LISTEN_PORT']
# 2025-09-24 03:02:38,785 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__WS_TOKEN'
# 2025-09-24 03:02:38,785 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'WS_TOKEN']
# 2025-09-24 03:02:38,785 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__EXCHANGE__KEY'
# 2025-09-24 03:02:38,786 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['EXCHANGE', 'KEY']
# 2025-09-24 03:02:38,786 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__EXCHANGE__SECRET'
# 2025-09-24 03:02:38,786 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['EXCHANGE', 'SECRET']
# 2025-09-24 03:02:38,787 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__TELEGRAM__CHAT_ID'
# 2025-09-24 03:02:38,787 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['TELEGRAM', 'CHAT_ID']
# 2025-09-24 03:02:38,787 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__TELEGRAM__TOKEN'
# 2025-09-24 03:02:38,787 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['TELEGRAM', 'TOKEN']
# 2025-09-24 03:02:38,787 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__WEBHOOK__URL'
# 2025-09-24 03:02:38,788 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['WEBHOOK', 'URL']
# 2025-09-24 03:02:38,789 - freqtrade.loggers - INFO - Enabling colorized output.
# 2025-09-24 03:02:38,790 - freqtrade.loggers - INFO - Logfile configured
# 2025-09-24 03:02:38,790 - freqtrade.loggers - INFO - Verbosity set to 0
# 2025-09-24 03:02:38,790 - freqtrade.configuration.configuration - WARNING -
# `force_entry_enable` RPC message enabled.
# 2025-09-24 03:02:38,790 - freqtrade.configuration.configuration - INFO -
# Parameter -i/--timeframe detected ... Using timeframe: 5m ...
# 2025-09-24 03:02:38,791 - freqtrade.configuration.configuration - INFO -
# Parameter --timerange detected: 20240101-20240630 ...
# 2025-09-24 03:02:38,877 - freqtrade.configuration.configuration - INFO - Using
# user-data directory: /freqtrade/user_data ...
# 2025-09-24 03:02:38,878 - freqtrade.configuration.configuration - INFO - Using
# data directory: /freqtrade/user_data/data/binance ...
# 2025-09-24 03:02:38,878 - freqtrade.configuration.configuration - INFO - Using
# pairs ['BTC/USDT']
# 2025-09-24 03:02:38,879 - freqtrade.configuration.configuration - INFO -
# Limiting plot to: 750
# 2025-09-24 03:02:38,879 - freqtrade.configuration.configuration - INFO - Using
# trades from: file
# 2025-09-24 03:02:38,879 - freqtrade.configuration.configuration - INFO - Filter
# trades by timerange: 20240101-20240630
# 2025-09-24 03:02:38,880 - freqtrade.exchange.check_exchange - INFO - Checking
# exchange...
# 2025-09-24 03:02:38,890 - freqtrade.exchange.check_exchange - INFO - Exchange
# "binance" is officially supported by the Freqtrade development team.
# 2025-09-24 03:02:38,890 - freqtrade.configuration.config_validation - INFO -
# Validating configuration ...
# 2025-09-24 03:02:38,929 - freqtrade.resolvers.iresolver - INFO - Using resolved
# strategy ichiV1 from '/freqtrade/user_data/strategies/ichiV1.py'...
# 2025-09-24 03:02:38,929 - freqtrade.strategy.hyper - INFO - Found no parameter
# file.
# 2025-09-24 03:02:38,930 - freqtrade.resolvers.strategy_resolver - WARNING -
# DEPRECATED: Using 'sell_profit_only' moved to 'exit_profit_only'.
# 2025-09-24 03:02:38,930 - freqtrade.resolvers.strategy_resolver - WARNING -
# DEPRECATED: Using 'use_sell_signal' moved to 'use_exit_signal'.
# 2025-09-24 03:02:38,931 - freqtrade.resolvers.strategy_resolver - WARNING -
# DEPRECATED: Using 'ignore_roi_if_buy_signal' moved to
# 'ignore_roi_if_entry_signal'.
# 2025-09-24 03:02:38,931 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'timeframe' with value from the configuration: 5m.
# 2025-09-24 03:02:38,931 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'stake_currency' with value from the configuration: USDT.
# 2025-09-24 03:02:38,932 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'stake_amount' with value from the configuration: 20.
# 2025-09-24 03:02:38,932 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'unfilledtimeout' with value from the configuration: {'entry':
# 10, 'exit': 10, 'exit_timeout_count': 0, 'unit': 'minutes'}.
# 2025-09-24 03:02:38,932 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'max_open_trades' with value from the configuration: 5.
# 2025-09-24 03:02:38,932 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using minimal_roi: {'0': 0.059, '10': 0.037, '41': 0.012, '114': 0}
# 2025-09-24 03:02:38,933 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using timeframe: 5m
# 2025-09-24 03:02:38,933 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stoploss: -0.275
# 2025-09-24 03:02:38,933 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_stop: False
# 2025-09-24 03:02:38,933 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_stop_positive_offset: 0.0
# 2025-09-24 03:02:38,933 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_only_offset_is_reached: False
# 2025-09-24 03:02:38,934 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using use_custom_stoploss: False
# 2025-09-24 03:02:38,934 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using process_only_new_candles: False
# 2025-09-24 03:02:38,934 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using order_types: {'entry': 'limit', 'exit': 'limit', 'stoploss':
# 'limit', 'stoploss_on_exchange': False, 'stoploss_on_exchange_interval': 60}
# 2025-09-24 03:02:38,934 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using order_time_in_force: {'entry': 'GTC', 'exit': 'GTC'}
# 2025-09-24 03:02:38,935 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stake_currency: USDT
# 2025-09-24 03:02:38,935 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stake_amount: 20
# 2025-09-24 03:02:38,935 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using startup_candle_count: 96
# 2025-09-24 03:02:38,935 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using unfilledtimeout: {'entry': 10, 'exit': 10, 'exit_timeout_count':
# 0, 'unit': 'minutes'}
# 2025-09-24 03:02:38,936 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using use_exit_signal: True
# 2025-09-24 03:02:38,936 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using exit_profit_only: False
# 2025-09-24 03:02:38,936 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using ignore_roi_if_entry_signal: False
# 2025-09-24 03:02:38,936 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using exit_profit_offset: 0.0
# 2025-09-24 03:02:38,936 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using disable_dataframe_checks: False
# 2025-09-24 03:02:38,937 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using ignore_buying_expired_candle_after: 0
# 2025-09-24 03:02:38,937 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using position_adjustment_enable: False
# 2025-09-24 03:02:38,937 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using max_entry_position_adjustment: -1
# 2025-09-24 03:02:38,937 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using max_open_trades: 5
# 2025-09-24 03:02:38,938 - freqtrade.exchange.exchange - INFO - Instance is
# running with dry_run enabled
# 2025-09-24 03:02:38,938 - freqtrade.exchange.exchange - INFO - Using CCXT 4.5.4
# 2025-09-24 03:02:38,954 - freqtrade.exchange.exchange - INFO - Using Exchange
# "Binance"
# 2025-09-24 03:02:40,951 - freqtrade.resolvers.exchange_resolver - INFO - Using
# resolved exchange 'Binance'...
# 2025-09-24 03:02:40,952 - freqtrade.strategy.hyper - INFO - No params for
# protection found, using default values.
# 2025-09-24 03:02:41,034 - freqtrade.data.history.datahandlers.idatahandler -
# WARNING - BTC/USDT, spot, 5m, data starts at 2024-01-01 00:00:00
# 2025-09-24 03:02:41,075 - freqtrade.plot.plotting - INFO - Loading data from
# 2024-01-01 00:00:00+00:00 to 2024-06-30 00:00:00+00:00
# 2025-09-24 03:02:41,076 - freqtrade.configuration.timerange - WARNING - Moving
# start-date by 96 candles to account for startup time.
# 2025-09-24 03:02:41,076 - freqtrade - ERROR - Fatal exception!
# Traceback (most recent call last):
#   File "/freqtrade/freqtrade/main.py", line 47, in main
#     return_code = args["func"](args)
#   File "/freqtrade/freqtrade/commands/plot_commands.py", line 26, in
# start_plot_dataframe
#     load_and_plot_trades(config)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/freqtrade/freqtrade/plot/plotting.py", line 642, in
# load_and_plot_trades
#     plot_elements = init_plotscript(config, list(exchange.markets),
# strategy.startup_candle_count)
#   File "/freqtrade/freqtrade/plot/plotting.py", line 82, in init_plotscript
#     if not filename.is_dir() and not filename.is_file():
#            ^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'is_dir'

# %%
# !docker compose run --rm freqtrade plot-dataframe \
  --strategy ichiV1 \
  --config /freqtrade/user_data/config_ichiV1.json \
  --config /freqtrade/user_data/config_plot.json \
  --db-url sqlite:////freqtrade/user_data/trades_ichiV1.sqlite \
  --pairs BTC/USDT --timeframe 5m --timerange 20250101-20250131

# %%
# !docker compose run --rm freqtrade plot-dataframe \
  --strategy ichiV1 \
  --config /freqtrade/user_data/config_ichiV1.json \
  --config /freqtrade/user_data/config_plot.json \
  --pairs BTC/USDT --timeframe 5m \
  --plot-limit 200 \
  --no-trades
# Out:
# 2025-09-24 05:21:47,902 - freqtrade - INFO - freqtrade
# docker-2025.9-dev-f6e1442f
# 2025-09-24 05:21:48,285 - numexpr.utils - INFO - NumExpr defaulting to 10
# threads.
# 2025-09-24 05:21:49,310 - freqtrade.configuration.load_config - INFO - Using
# config: /freqtrade/user_data/config_ichiV1.json ...
# 2025-09-24 05:21:49,313 - freqtrade.configuration.load_config - INFO - Using
# config: /freqtrade/user_data/config_plot.json ...
# 2025-09-24 05:21:49,314 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__JWT_SECRET_KEY'
# 2025-09-24 05:21:49,314 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'JWT_SECRET_KEY']
# 2025-09-24 05:21:49,315 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__LISTEN_IP_ADDRESS'
# 2025-09-24 05:21:49,315 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'LISTEN_IP_ADDRESS']
# 2025-09-24 05:21:49,315 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__LISTEN_PORT'
# 2025-09-24 05:21:49,316 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'LISTEN_PORT']
# 2025-09-24 05:21:49,316 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__API_SERVER__WS_TOKEN'
# 2025-09-24 05:21:49,316 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['API_SERVER', 'WS_TOKEN']
# 2025-09-24 05:21:49,316 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__EXCHANGE__KEY'
# 2025-09-24 05:21:49,317 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['EXCHANGE', 'KEY']
# 2025-09-24 05:21:49,317 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__EXCHANGE__SECRET'
# 2025-09-24 05:21:49,317 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['EXCHANGE', 'SECRET']
# 2025-09-24 05:21:49,317 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__TELEGRAM__CHAT_ID'
# 2025-09-24 05:21:49,318 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['TELEGRAM', 'CHAT_ID']
# 2025-09-24 05:21:49,318 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__TELEGRAM__TOKEN'
# 2025-09-24 05:21:49,318 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['TELEGRAM', 'TOKEN']
# 2025-09-24 05:21:49,318 - freqtrade.configuration.environment_vars - INFO -
# Loading variable 'FREQTRADE__WEBHOOK__URL'
# 2025-09-24 05:21:49,318 - freqtrade.configuration.environment_vars - INFO - Key
# parts: ['WEBHOOK', 'URL']
# 2025-09-24 05:21:49,320 - freqtrade.loggers - INFO - Enabling colorized output.
# 2025-09-24 05:21:49,321 - freqtrade.loggers - INFO - Logfile configured
# 2025-09-24 05:21:49,321 - freqtrade.loggers - INFO - Verbosity set to 0
# 2025-09-24 05:21:49,321 - freqtrade.configuration.configuration - WARNING -
# `force_entry_enable` RPC message enabled.
# 2025-09-24 05:21:49,321 - freqtrade.configuration.configuration - INFO -
# Parameter -i/--timeframe detected ... Using timeframe: 5m ...
# 2025-09-24 05:21:49,473 - freqtrade.configuration.configuration - INFO - Using
# user-data directory: /freqtrade/user_data ...
# 2025-09-24 05:21:49,474 - freqtrade.configuration.configuration - INFO - Using
# data directory: /freqtrade/user_data/data/binance ...
# 2025-09-24 05:21:49,474 - freqtrade.configuration.configuration - INFO - Using
# pairs ['BTC/USDT']
# 2025-09-24 05:21:49,474 - freqtrade.configuration.configuration - INFO -
# Limiting plot to: 200
# 2025-09-24 05:21:49,475 - freqtrade.configuration.configuration - INFO - Using
# trades from: file
# 2025-09-24 05:21:49,475 - freqtrade.configuration.configuration - INFO -
# Parameter --no-trades detected.
# 2025-09-24 05:21:49,476 - freqtrade.exchange.check_exchange - INFO - Checking
# exchange...
# 2025-09-24 05:21:49,492 - freqtrade.exchange.check_exchange - INFO - Exchange
# "binance" is officially supported by the Freqtrade development team.
# 2025-09-24 05:21:49,493 - freqtrade.configuration.config_validation - INFO -
# Validating configuration ...
# 2025-09-24 05:21:49,526 - freqtrade.resolvers.iresolver - INFO - Using resolved
# strategy ichiV1 from '/freqtrade/user_data/strategies/ichiV1.py'...
# 2025-09-24 05:21:49,526 - freqtrade.strategy.hyper - INFO - Found no parameter
# file.
# 2025-09-24 05:21:49,527 - freqtrade.resolvers.strategy_resolver - WARNING -
# DEPRECATED: Using 'sell_profit_only' moved to 'exit_profit_only'.
# 2025-09-24 05:21:49,527 - freqtrade.resolvers.strategy_resolver - WARNING -
# DEPRECATED: Using 'use_sell_signal' moved to 'use_exit_signal'.
# 2025-09-24 05:21:49,527 - freqtrade.resolvers.strategy_resolver - WARNING -
# DEPRECATED: Using 'ignore_roi_if_buy_signal' moved to
# 'ignore_roi_if_entry_signal'.
# 2025-09-24 05:21:49,528 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'timeframe' with value from the configuration: 5m.
# 2025-09-24 05:21:49,528 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'stake_currency' with value from the configuration: USDT.
# 2025-09-24 05:21:49,528 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'stake_amount' with value from the configuration: 20.
# 2025-09-24 05:21:49,529 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'unfilledtimeout' with value from the configuration: {'entry':
# 10, 'exit': 10, 'exit_timeout_count': 0, 'unit': 'minutes'}.
# 2025-09-24 05:21:49,529 - freqtrade.resolvers.strategy_resolver - INFO -
# Override strategy 'max_open_trades' with value from the configuration: 5.
# 2025-09-24 05:21:49,529 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using minimal_roi: {'0': 0.059, '10': 0.037, '41': 0.012, '114': 0}
# 2025-09-24 05:21:49,530 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using timeframe: 5m
# 2025-09-24 05:21:49,530 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stoploss: -0.275
# 2025-09-24 05:21:49,530 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_stop: False
# 2025-09-24 05:21:49,530 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_stop_positive_offset: 0.0
# 2025-09-24 05:21:49,530 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using trailing_only_offset_is_reached: False
# 2025-09-24 05:21:49,531 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using use_custom_stoploss: False
# 2025-09-24 05:21:49,531 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using process_only_new_candles: False
# 2025-09-24 05:21:49,531 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using order_types: {'entry': 'limit', 'exit': 'limit', 'stoploss':
# 'limit', 'stoploss_on_exchange': False, 'stoploss_on_exchange_interval': 60}
# 2025-09-24 05:21:49,531 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using order_time_in_force: {'entry': 'GTC', 'exit': 'GTC'}
# 2025-09-24 05:21:49,531 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stake_currency: USDT
# 2025-09-24 05:21:49,532 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using stake_amount: 20
# 2025-09-24 05:21:49,532 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using startup_candle_count: 96
# 2025-09-24 05:21:49,532 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using unfilledtimeout: {'entry': 10, 'exit': 10, 'exit_timeout_count':
# 0, 'unit': 'minutes'}
# 2025-09-24 05:21:49,532 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using use_exit_signal: True
# 2025-09-24 05:21:49,532 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using exit_profit_only: False
# 2025-09-24 05:21:49,533 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using ignore_roi_if_entry_signal: False
# 2025-09-24 05:21:49,533 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using exit_profit_offset: 0.0
# 2025-09-24 05:21:49,533 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using disable_dataframe_checks: False
# 2025-09-24 05:21:49,534 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using ignore_buying_expired_candle_after: 0
# 2025-09-24 05:21:49,534 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using position_adjustment_enable: False
# 2025-09-24 05:21:49,534 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using max_entry_position_adjustment: -1
# 2025-09-24 05:21:49,534 - freqtrade.resolvers.strategy_resolver - INFO -
# Strategy using max_open_trades: 5
# 2025-09-24 05:21:49,535 - freqtrade.exchange.exchange - INFO - Instance is
# running with dry_run enabled
# 2025-09-24 05:21:49,535 - freqtrade.exchange.exchange - INFO - Using CCXT 4.5.4
# 2025-09-24 05:21:49,552 - freqtrade.exchange.exchange - INFO - Using Exchange
# "Binance"
# 2025-09-24 05:21:54,773 - freqtrade.exchange.common - WARNING -
# _load_async_markets() returned exception: "Error in reload_markets due to
# ExchangeNotAvailable. Message: binance GET
# https://api.binance.com/api/v3/exchangeInfo". Retrying still for 3 times.
# 2025-09-24 05:21:57,281 - freqtrade.resolvers.exchange_resolver - INFO - Using
# resolved exchange 'Binance'...
# 2025-09-24 05:21:57,282 - freqtrade.strategy.hyper - INFO - No params for
# protection found, using default values.
# 2025-09-24 05:21:57,414 - freqtrade.plot.plotting - INFO - Loading data from
# 2024-01-01 00:00:00+00:00 to 2025-09-21 13:50:00+00:00
# 2025-09-24 05:21:57,415 - freqtrade.configuration.timerange - WARNING - Moving
# start-date by 96 candles to account for startup time.
# 2025-09-24 05:21:57,416 - freqtrade.plot.plotting - INFO - analyse pair BTC/USDT
# 2025-09-24 05:22:02,824 - freqtrade.plot.plotting - WARNING - No trades found.
# 2025-09-24 05:22:02,832 - freqtrade.plot.plotting - INFO - Generate plot file
# for BTC/USDT
# 2025-09-24 05:22:03,925 - freqtrade.plot.plotting - INFO - Stored plot as
# /freqtrade/user_data/plot/freqtrade-plot-BTC_USDT-5m.html
# 2025-09-24 05:22:03,927 - freqtrade.plot.plotting - INFO - End of plotting
# process. 1 plots generated

# %% [markdown]
# ## 5.
